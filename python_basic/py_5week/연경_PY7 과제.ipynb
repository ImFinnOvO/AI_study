# %% [markdown]
# ### **p.319 random 모듈**

# %%
import random
print("# random 모듈")

# random(): 0.0 <= x < 1.0 사이의 float를 리턴합니다. 
print("= random():", random.random())

# uniform(min,max): 지정한 범위 사이의 float를 리턴합니다. 
print("- uniform(10,20):", random.uniform(10,20))

# randrange(): 지정한 범위의 int를 입력합니다. 
# -randrange(max): 0부터 max 사이의 값을 리턴합니다. 
# - randrange(min,max): min부터 max 사이의 값을 리턴합니다. 
print("- randrange(10):", random.randrange(10))

# choice(list): 리스트 내부에 있는 요소를 랜덤하게 선택합니다. 
print("- choice([1, 2, 3, 4, 5]):", random.choice([1, 2, 3, 4, 5]))

# shuffle(list): 리스트의 요소들을 랜덤하게 섞습니다. 
print("- shuffle([1, 2, 3, 4, 5]):", random.shuffle([1, 2, 3, 4, 5]))

# sample(list, k=<숫자>): 리스트의 요소 중에 k개를 뽑습니다. 
print("- sample([1, 2, 3, 4, 5], k=2):", random.sample([1, 2, 3, 4, 5], k=2))
# Out:
# # random 모듈
# = random(): 0.6817317917507546
# - uniform(10,20): 14.30736966297495
# - randrange(10): 0
# - choice([1, 2, 3, 4, 5]): 1
# - shuffle([1, 2, 3, 4, 5]): None
# - sample([1, 2, 3, 4, 5], k=2): [1, 4]

# %% [markdown]
# ### **p.320 sys 모듈**

# %%
# 모듈을 읽어 들입니다. 
import sys

# 명령 매개변수를 출력합니다.
print(sys.argv)
print("---")

# 컴퓨터 환경과 관련된 정보를 출력합니다. 
print("getwindowsversion:()", sys.getwindowsversion())
print("---")
print("copyright:", sys.copyright)
print("---")
print("version:", sys.version)

# 프로그램을 강제 종료합니다.
sys.exit()
# Out:
# ['/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-bcae0817-7627-4b60-b3cc-d6514c9ad2e3.json']
# ---
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-a5f7e997c54a> in <module>()
#       7
#       8 # 컴퓨터 환경과 관련된 정보를 출력합니다.
# ----> 9 print("getwindowsversion:()", sys.getwindowsversion())
#      10 print("---")
#      11 print("copyright:", sys.copyright)
#
# AttributeError: module 'sys' has no attribute 'getwindowsversion'

# %% [markdown]
# ### **p.322 os 모듈**

# %%
# 모듈을 읽어들입니다. 
import os

# 기본 정보를 몇 개 출력해 봅시다. 
print("현재 운영체제:", os.name)
print("현재 폴더:", os.getcwd())
print("현재 폴더 내부의 요소:", os.listdir())

# 폴더를 만들고 제거합니다[폴더가 비어있을 때만 제거 가능].
os.mkdir("hello")
os.rmdir("hello")

# 파일을 생성하고 + 파일 이름을 변경합니다. 
with open("original.txt", "w") as file:
     file.write("heiio")
os.rename("original.txt", "new.txt")

# 파일을 제거합니다. 
os.remove("new.txt")
# os.unlink("new.txt")

# 시스템 명령어 실행
os.system("dir")
# Out:
# 현재 운영체제: posix
# 현재 폴더: /content
# 현재 폴더 내부의 요소: ['.config', 'sample_data']
# 0

# %% [markdown]
# ### **p.324 datetime 모듈**

# %%
# 모듈을 읽어들입니다. 
import datetime

# 현재 시각을 구하고 출력하기
print("# 현재 시각 출력하기")
now = datetime.datetime.now()
print(now.year, "년")
print(now. month, "월")
print(now.day, "일")
print(now.hour, "시")
print(now.minute, "분")
print(now.second, "초")
print()

# 시간 출력 방법
print("# 시간을 포맷에 맞춰 출력하기")
output_a = now.strftime("%Y.%m.%d %H:%M:%S")
output_b = "{}년 {}월 {}일 {}시 {}분 {}초".format(now.year,\
    now.month,\
    now.day,\
    now.hour,\
    now.minute,\
    now.second )
output_c = now.strftime("%Y{} %m{} %d{} %H{} %M{} %S{}").format(*"년월일시분초")
print(output_a)
print(output_b)
print(output_c)
print()
# Out:
# # 현재 시각 출력하기
# 2021 년
# 10 월
# 13 일
# 17 시
# 57 분
# 8 초
#
# # 시간을 포맷에 맞춰 출력하기
# 2021.10.13 17:57:08
# 2021년 10월 13일 17시 57분 8초
# 2021년 10월 13일 17시 57분 08초

# %% [markdown]
# ### **p.325 시간 처리하기**

# %%
# 모듈을 읽어들입니다.
import datetime
now = datetime.datetime.now()

# 특정 시간 이후의 시간 구하기
print("# datetime.timedelta로 시간 더하기")
after = now + datetime.timedelta(\
    weeks=1,\
    days=1,\
    hours=1,\
    minutes=1,\
    seconds=1)                             
print(after.strftime("%Y{} %m{} %d{} %H{} %M{} %S{}").format(*"년월일시분초"))
print()

# 특정 시간 요소 교체하기
print("# now.replace()로 1년 더하기")
output = now.replace(year=(now.year + 1))
print(output.strftime("%Y{} %m{} %d{} %H{} %M{} %S{}").format(*"년월일시분초"))
# Out:
# # datetime.timedelta로 시간 더하기
# 2021년 10월 21일 19시 04분 06초
#
# # now.replace()로 1년 더하기
# 2022년 10월 13일 18시 03분 05초

# %% [markdown]
# ### **p.326 time 모듈**

# %%
import time

print("지금부터 5초 동안 정지합니다!")
time.sleep(5)
print("프로그램을 종료합니다")
# Out:
# 지금부터 5초 동안 정지합니다!
# 프로그램을 종료합니다

# %% [markdown]
# ### **p.327 urllib 모듈**

# %%
# 모듈을 읽어들입니다.
from urllib import request

# urlopen() 함수로 구글의 메인 페이지를 읽습니다. 
target = request.urlopen("https://google.com")
output = target.read()

# 출력합니다. 
print(output)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world\'s information, including webpages, images, videos and more. Google has many special features to help you find exactly what you\'re looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="za3+uxCLEJZ1sap0c1APrw==">(function(){window.google={kEI:\'UyBnYd_AGYrVtAbMp4k4\',kEXPI:\'0,1302536,56873,6058,207,2414,2390,925,1391,383,246,5,1354,4936,314,1122516,1197779,112,510,328866,51223,16115,28684,17572,4858,1362,9290,3030,17579,4020,978,13228,3847,4192,6430,1142,17902,2778,919,5081,1593,1279,2212,530,149,1103,840,1983,214,4100,3514,606,2023,1777,520,1704,12966,3227,2845,7,5599,6755,5096,14396,1924,908,2,940,2615,12710,432,3,346,1244,1,5444,149,11323,2652,4,1528,2304,1236,5227,576,74,1983,2627,2014,11501,3824,1011,2039,2658,7357,30,13628,2305,638,37,1457,15351,1435,652,1869,3309,2527,992,3102,17,3121,6,908,3,3541,1,5096,1,2,2,248,6593,2768,1,1813,283,914,5990,1160,13518,769,8,1,1272,1715,2,9212,627,4,50,4,4125,1244,4,683,442,342,255,55,4,189,2,303,256,2184,286,1271,126,618,5852,8874,1589,1160,6699,301,19,2061,2718,3709,2,835,3,5473,4148,487,3640,1,8,4925,2792,2125,2443,243,2335,1766,1370,274,265,4393,2,2243,91,1,3054,719,3,2395,2961,1940,287,314,231,3801,75,2756,1584,1105,466,843,1,8,777,41,1175,409,5,482,16,883,723,1086,98,2621,116,572,68,1572,894,454,3,831,308,616,2,1023,275,1080,75,55,1,5,3,1,3,1,3,214,1257,405,465,468,2,1299,3,2,52,65,2,91,280,408,996,4,39,413,341,225,134,198,759,531,122,163,687,725,60,1759,21,2,2,1,475,439,2,212,5557888,446,160,161,64,1802504,95,4193885,2800696,882,444,1,2,80,1,1796,1,9,2553,1,748,141,795,563,1,4265,1,1,2,1331,4142,2609,155,17,13,72,139,4,2,20,2,169,13,19,46,5,39,96,548,29,2,2,1,2,1,2,2,7,4,1,2,2,2,2,2,2,353,513,186,1,1,158,3,2,2,2,2,2,4,2,3,3,269,465,86,13,4,4,3,5,99,4,2,75,51,6,29,5,2,6,6,2,2,4,2,6,22,5,15,5,8,23953787,2862026,1176544,3,2778,338,3,2414,1491,9,1434,1516,293,838,1583,507,344,1584,140\',kBL:\'iMdx\'};google.sn=\'webhp\';google.kHL=\'en\';})();(function(){\nvar f=this||self;var h,k=[];function l(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||h}function m(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}\nfunction n(a,b,c,d,g){var e="";c||-1!==b.search("&ei=")||(e="&ei="+l(d),-1===b.search("&lei=")&&(d=m(d))&&(e+="&lei="+d));d="";!c&&f._cshid&&-1===b.search("&cshid=")&&"slh"!==a&&(d="&cshid="+f._cshid);c=c||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e+"&zx="+Date.now()+d;/^http:/i.test(c)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:c,glmm:1}),c="");return c};h=google.kEI;google.getEI=l;google.getLEI=m;google.ml=function(){return null};google.log=function(a,b,c,d,g){if(c=n(a,b,c,d,g)){a=new Image;var e=k.length;k[e]=a;a.onerror=a.onload=a.onabort=function(){delete k[e]};a.src=c}};google.logUrl=n;}).call(this);(function(){\ngoogle.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a ...

# %% [markdown]
# ### **p.336 BeautifulSoup 모듈로 날씨 가져오기**

# %%
# 모듈을 읽어 들입니다. 
from urllib import request
from bs4 import BeautifulSoup

# urlopen() 함수로 기상청의 전국 날씨를 읽습니다. 
target = request.urlopen("http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108")

# BeautifulSoup을 사용해 웹 페이지를 분석합니다. 
soup = BeautifulSoup(target, "html.parser")

# location 태그를 찾습니다. 
for location in soup.select("location"):
    # 내부의 city, wf, tmn, tmx 태그를 찾아 출력합니다. 
    print("도시:", location.select_one("city").string)
    print("날씨:", location.select_one("wf").string)
    print("최저기온:", location.select_one("tmn").string)
    print("최고기온:", location.select_one("tmx").string)
    print()
# Out:
# 도시: 서울
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 14
#
# 도시: 인천
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 13
#
# 도시: 수원
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 16
#
# 도시: 파주
# 날씨: 구름많음
# 최저기온: 10
# 최고기온: 14
#
# 도시: 이천
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 16
#
# 도시: 평택
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 15
#
# 도시: 춘천
# 날씨: 흐림
# 최저기온: 14
# 최고기온: 16
#
# 도시: 원주
# 날씨: 흐림
# 최저기온: 13
# 최고기온: 16
#
# 도시: 강릉
# 날씨: 흐리고 비
# 최저기온: 15
# 최고기온: 19
#
# 도시: 대전
# 날씨: 흐리고 비
# 최저기온: 14
# 최고기온: 16
#
# 도시: 세종
# 날씨: 흐리고 비
# 최저기온: 14
# 최고기온: 16
#
# 도시: 홍성
# 날씨: 흐리고 비
# 최저기온: 13
# 최고기온: 15
#
# 도시: 청주
# 날씨: 흐리고 비
# 최저기온: 14
# 최고기온: 16
#
# 도시: 충주
# 날씨: 흐리고 비
# 최저기온: 13
# 최고기온: 16
#
# 도시: 영동
# 날씨: 흐리고 비
# 최저기온: 13
# 최고기온: 17
#
# 도시: 광주
# 날씨: 흐리고 비
# 최저기온: 16
# 최고기온: 17
#
# 도시: 목포
# 날씨: 흐리고 비
# 최저기온: 16
# 최고기온: 18
#
# 도시: 여수
# 날씨: 흐리고 비
# 최저기온: 18
# 최고기온: 19
#
# 도시: 순천
# 날씨: 흐리고 비
# 최저기온: 17
# 최고기온: 19
#
# 도시: 광양
# 날씨: 흐리고 비
# 최저기온: 17
# 최고기온: 18
#
# 도시: 나주
# 날씨: 흐리고 비
# 최저기온: 14
# 최고기온: 17
#
# 도시: 전주
# 날씨: 흐리고 비
# 최저기온: 15
# 최고기온: 17
#
# 도시: 군산
# 날씨: 흐리고 비
# 최저기온: 15
# 최고기온: 17
#
# 도시: 정읍
# 날씨: 흐리고 비
# 최저기온: 14
# 최고기온: 17
#
# 도시: 남원
# 날씨: 흐리고 비
# 최저기온: 15
# 최고기온: 16
#
# 도시: 고창
# 날씨: 흐리고 비
# 최저기온: 15
# 최고기온: 16
#
# 도시: 무주
# 날씨: 흐리고 비
# 최저기온: 13
# 최고기온: 16
#
# 도시: 부산
# 날씨: 흐리고 비
# 최저기온: 18
# 최고기온: 20
#
# 도시: 울산
# 날씨: 흐리고 비
# 최저기온: 17
# 최고기온: 19
#
# 도시: 창원
# 날씨: 흐리고 비
# 최저기온: 17
# 최고기온: 19
#
# 도시: 진주
# 날씨: 흐리고 비
# 최저기온: 16
# 최고기온: 19
#
# 도시: 거창
# 날씨: 흐리고 비
# 최저기온: 14
# 최고기온: 17
#
# 도시: 통영
# 날씨: 흐리고 비
# 최저기온: 18
# 최고기온: 20
#
# 도시: 대구
# 날씨: 흐리고 비
# 최저기온: 17
# 최고기온: 19
#
# 도시: 안동
# 날씨: 흐리고 비
# 최저기온: 15
# 최고기온: 18
#
# 도시: 포항
# 날씨: 흐리고 비
# 최저기온: 18
# 최고기온: 19
#
# 도시: 경주
# 날씨: 흐리고 비
# 최저기온: 17
# 최고기온: 17
#
# 도시: 울진
# 날씨: 흐리고 비
# 최저기온: 15
# 최고기온: 19
#
# 도시: 울릉도
# 날씨: 흐리고 비
# 최저기온: 15
# 최고기온: 17
#
# 도시: 제주
# 날씨: 흐리고 비
# 최저기온: 19
# 최고기온: 20
#
# 도시: 서귀포
# 날씨: 흐리고 비
# 최저기온: 19
# 최고기온: 20

# %% [markdown]
# ### **p.339 Flask 모듈 사용하기**

# %%
from flask import Flask
app = Flask(__name__)

@app.route("/")
def hello():
   return "<h1>Hello World!</h1>"

# %% [markdown]
# ### **p.341 BeautifulSoup 스크레이핑 실핼하기**
#
# ---

# %%
# 모듈을 읽어들입니다. 
from flask import Flask
from urllib import request
from bs4 import BeautifulSoup

# 웹 서버를 생성합니다. 
app = Flask(__name__)
@app.route("/")

def hello():
    # urlopen() 함수로 기상청의 전국 날씨를 읽습니다. 
    target = request.urlopen("http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108")

    # BeautifulSoup를 사용해 웹 페이지를 분석합니다. 
    soup = BeautifulSoup(target, "html.parser")

    # location 태그를 찾습니다. 
    output = ""
    for location in soup.select("location"):
        # 내부의 city, wf, tmn, tmx 태그를 찾아 출력합니다. 
        output += "<h3>{}</h3>".format(location.select_one("city").string)
        output += "날씨: {}<br/>".format(location.select_one("wf").string)
        output += "최저/최고 기온: {}/{}"\
            .format(\
                location.select_one('tmn').string,\
                location.select_one("tmx").string\
                )
            
        output += "<hr/>"
    return output
